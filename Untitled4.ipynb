# %%
#importação de bibliotecas
import math

# %%
#inteiro
e = 5
print("e:",e)
m = 8
print("m:",m)
largconjunto = 2
print("largconjunto:",largconjunto)
camplinha = 2
print("camplinha:",camplinha)
campcelula = 1
print("campcelula:",campcelula)
campconjunto = 0
print("campconjunto:",campconjunto)
qtdlinhas = 4
print("qtdlinhas:",qtdlinhas)

#calculos
n = int(2**e)
print("n:",n)
tmp = m*n
print("tmp:",tmp)
campTAGa = e - camplinha - campcelula
print("campTAGa:",campTAGa)
campTAGd = e  - campcelula
print("campTAGd:",campTAGd)
campTAGac = e - campconjunto - campcelula
print("campTAGac:",campTAGac)

largblocos = int(n/2)
print("largblocos:",largblocos)
larglinhas = largblocos
print("larglinhas:",larglinhas)

qtdblocos = n/(largblocos/m)
print("qtdblocos:",qtdblocos)
qtdconjuntos = qtdlinhas/largconjunto
print("qtdconjuntos:",qtdconjuntos)



#mdTAG = []
#mdE = []

# %%
#CACHE
mdadoscache1 = []
caixaE1 = ["",""]
mdadoscache2 = []
caixaE2 = ["",""]
mdadoscache3 = []
caixaE3 = ["",""]
mdadoscache4 = []
caixaE4 = ["",""]

for i in range(2):
    mdadoscache1.append("00000000")
    print(mdadoscache1[i])
print("mdadoscache1:",len(mdadoscache1))

for i in range(2):
    mdadoscache2.append("00000000")
    print(mdadoscache2[i])
print("mdadoscache1:",len(mdadoscache2))

for i in range(2):
    mdadoscache3.append("00000000")
    print(mdadoscache3[i])
print("mdadoscache3:",len(mdadoscache3))

for i in range(2):
    mdadoscache4.append("00000000")
    print(mdadoscache4[i])
print("mdadoscache4:",len(mdadoscache4))

# %%
#MP
mdadosmp = []
for i in range(n):
    mdadosmp.append(format(i,'08b'))
    print(mdadosmp[i])
print("mdadosmp:",len(mdadosmp))

# %%
#comparador
tl1 = []
tl2 = []
tl3 = []
tl4 = []
x=0
for i in range(camplinha+campTAGa): 
    tl1.append(format(i+x,'04b'))
    x+=1
    tl2.append(format(i+x,'04b'))
    x+=1
    tl3.append(format(i+x,'04b'))
    x+=1
    tl4.append(format(i+x,'04b'))
    
print(tl1)
print(tl2)
print(tl3)
print(tl4)

# %%
#str
Fim = "y"
while(Fim != "n"):
    REM = input("Forneça o endereço da célula (em binário):")
    #UC = input("Forneça E para escrita e L para leitura:")
    #RDM = input("Forneça o valor a ser escrito na célula em binário (8bits)")
    #quebra do endereço REM
    Ecelula = ""
    Elinha = ""
    Etaga = ""
    REMinvert = REM[::-1]
    for i in range(campcelula):
        Ecelula += REMinvert[i]
    Ecelula = Ecelula[::-1]
    #print("Ecelula:",Ecelula)

    for i in range(camplinha):
        Elinha += REMinvert[i+campcelula]
    Elinha = Elinha[::-1]
    #print("Elinha:",Elinha)

    for i in range(campTAGa):
        Etaga += REMinvert[i+campcelula+campTAGa]
    Etaga = Etaga[::-1]
    #print("Etaga:",Etaga)

    #buscador da cache
    falta = 0
    y = 0
    p=""
    for i in range(camplinha+campTAGa):
        if((Etaga+Elinha)==caixaE1[y]):
            #print(caixaE1[y])
            p = mdadoscache1[int(Ecelula)]
        else:
            falta = 1
        if((Etaga+Elinha)==caixaE2[y]):
            #print(caixaE2[y])
            p = mdadoscache2[int(Ecelula)]
        else:
            falta = 1
        if((Etaga+Elinha)==caixaE3[y]):
            #print(caixaE3[y])
            p = mdadoscache3[int(Ecelula)]
        else:
            falta = 1
        if((Etaga+Elinha)==caixaE4[y]):
            #print(caixaE4[y])
            p = mdadoscache4[int(Ecelula)]
        else:
            falta = 1
        y=1
    #print(p)
    #print(Etaga+Elinha)

    #solicitação de dado da mp pela cache e transporte de dados da mp para a cache
    if(falta == 1):
        BD = mdadosmp[int(REM,2)]
        Etl2 = ""
        #print(REM)
        #print(BD)

        for i in range(camplinha+campTAGa):
            if((Etaga+Elinha)==tl1[i]):
                caixaE1[int(Ecelula)] = Etaga+Elinha
                mdadoscache1[int(Ecelula)] = BD
                #print("caixaE1:",caixaE1[int(Ecelula)])
                if(int(Ecelula) == 1):
                    BE2 = int(REM,2)-1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)-1
                    caixaE1[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache1[Ecelula2] = BD2       
                if(int(Ecelula) == 0):
                    BE2 = int(REM,2)+1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)+1
                    caixaE1[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache1[Ecelula2] = BD2
                #print(mdadoscache1[iEcelula2])
                #print("caixaE1",caixaE1[Ecelula2])    

            if((Etaga+Elinha)==tl2[i]):
                caixaE2[int(Ecelula)] = Etaga+Elinha
                mdadoscache2[int(Ecelula)] = BD
                #print("caixaE2:",caixaE2[int(Ecelula)])
                if(int(Ecelula) == 1):
                    BE2 = int(REM,2)-1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)-1
                    caixaE2[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache2[Ecelula2] = BD2       
                if(int(Ecelula) == 0):
                    BE2 = int(REM,2)+1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)+1
                    caixaE2[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache2[Ecelula2] = BD2
                #print(mdadoscache2[iEcelula2])
                #print("caixaE2",caixaE2[Ecelula2])    

            if((Etaga+Elinha)==tl3[i]):
                caixaE3[int(Ecelula)] = Etaga+Elinha
                mdadoscache3[int(Ecelula)] = BD
                #print("caixaE3:",caixaE3[int(Ecelula)])
                if(int(Ecelula) == 1):
                    BE2 = int(REM,2)-1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)-1
                    caixaE3[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache3[Ecelula2] = BD2       
                if(int(Ecelula) == 0):
                    BE2 = int(REM,2)+1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)+1
                    caixaE3[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache3[Ecelula2] = BD2
                #print(mdadoscache3[iEcelula2])
                #print("caixaE3",caixaE3[Ecelula2])    

            if((Etaga+Elinha)==tl4[i]):
                caixaE4[int(Ecelula)] = Etaga+Elinha
                mdadoscache4[int(Ecelula)] = BD
                #print("caixaE4:",caixaE4[int(Ecelula)])
                if(int(Ecelula) == 1):
                    BE2 = int(REM,2)-1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)-1
                    caixaE4[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache4[Ecelula2] = BD2       
                if(int(Ecelula) == 0):
                    BE2 = int(REM,2)+1
                    REM2 = format(BE2,'05b')
                    for i in range(4):
                        Etl2 += REM2[i]
                        #print("Etl2:",Etl2)
                    Ecelula2 = int(Ecelula)+1
                    caixaE4[Ecelula2] = Etl2
                    BD2 = mdadosmp[int(REM2,2)]
                    mdadoscache4[Ecelula2] = BD2
                #print(mdadoscache4[Ecelula2])
                #print("caixaE4",caixaE4[Ecelula2]) 

    #print(mdadoscache4[int(Ecelula)])
    #print(mdadoscache3[int(Ecelula)])
    #print("bit2:",Ecelula2)
    #buscador da cache
    y = 0 
    for i in range(camplinha+campTAGa):
       # print(i)
        if((Etaga+Elinha)==caixaE1[y]):
           # print(caixaE4[y])
            p = mdadoscache1[int(Ecelula)]
            falta = 0
        if((Etaga+Elinha)==caixaE2[y]):
           # print(caixaE4[y])
            p = mdadoscache2[int(Ecelula)]
            falta = 0
        if((Etaga+Elinha)==caixaE3[y]):
           # print(caixaE4[y])
            p = mdadoscache3[int(Ecelula)]
            falta = 0
        if((Etaga+Elinha)==caixaE4[y]):
           # print(caixaE4[y])
            p = mdadoscache4[int(Ecelula)]
            falta = 0
        y=1

    print("Conteúdo da célula:",p)   
    print("Endereço da célula:",REM)
    Fim = input("Gostaria de realizar outra operação? y/n")
# Out:
# Forneça o endereço da célula (em binário):10110
# Conteúdo da célula: 00010110
# Endereço da célula: 10110
# Gostaria de realizar outra operação? y/ny
# Forneça o endereço da célula (em binário):10111
# Conteúdo da célula: 00010111
# Endereço da célula: 10111
